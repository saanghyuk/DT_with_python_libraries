# %%
import pandas as pd

# %%
names1880 = pd.read_csv('/Users/sanghyuk/Documents/data_analysis_with_python/pydata-book/datasets/babynames/yob1880.txt', names = ['name', 'sex', 'births'])\

# %%
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     794
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
years= range(1880, 2011)

# %%
pieces = []
columns = ['name', 'sex', 'births']

# %%
for year in years:
    path = '/Users/sanghyuk/Documents/data_analysis_with_python/pydata-book/datasets/babynames/yob%d.txt'%year
    frame = pd.read_csv(path, names = columns)
    frame['year']= year
    pieces.append(frame)

# %%
names = pd.concat(pieces,ignore_index = True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     794  1880
# 23          Jennie   F     793  1880
# ...

# %%
total_births = names.pivot_table('births', index='year', columns = 'sex', aggfunc = sum)

# %%
total_births
# Out:
# sex         F        M
# year
# 1880    90993   110493
# 1881    91955   100748
# 1882   107851   113687
# 1883   112322   104632
# 1884   129021   114445
# 1885   133056   107802
# 1886   144538   110785
# 1887   145983   101412
# 1888   178631   120857
# 1889   178369   110590
# 1890   190377   111026
# 1891   185486   101198
# 1892   212350   122038
# 1893   212908   112319
# 1894   222923   115775
# 1895   233632   117398
# 1896   237924   119575
# 1897   234199   112760
# 1898   258771   122703
# 1899   233022   106218
# 1900   299873   150554
# 1901   239351   106478
# 1902   264079   122660
# 1903   261976   119240
# 1904   275375   128129
# 1905   291641   132319
# 1906   295301   133159
# 1907   318558   146838
# 1908   334277   154339
# 1909   347191   163983
# ...       ...      ...
# 1981  1666833  1789568
# 1982  1692036  1812642
# 1983  1669486  1790670
# 1984  1682396  1802735
# 1985  1719450  1846162
# 1986  1714053  1839442
# 1987  1737508  1865113
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

total_births.plot(title='Total births by sex and year')

# %%
def add_prop(group):
    births= group.births
    group['prop'] =births/births.sum()
    return group

# %%
i= 0
for group in names.groupby(['year', 'sex']):
    if(i != 1):
        print(group)
# Out:
# ((1880, 'F'),           name sex  births  year
# 0         Mary   F    7065  1880
# 1         Anna   F    2604  1880
# 2         Emma   F    2003  1880
# 3    Elizabeth   F    1939  1880
# 4       Minnie   F    1746  1880
# 5     Margaret   F    1578  1880
# 6          Ida   F    1472  1880
# 7        Alice   F    1414  1880
# 8       Bertha   F    1320  1880
# 9        Sarah   F    1288  1880
# 10       Annie   F    1258  1880
# 11       Clara   F    1226  1880
# 12        Ella   F    1156  1880
# 13    Florence   F    1063  1880
# 14        Cora   F    1045  1880
# 15      Martha   F    1040  1880
# 16       Laura   F    1012  1880
# 17      Nellie   F     995  1880
# 18       Grace   F     982  1880
# 19      Carrie   F     949  1880
# 20       Maude   F     858  1880
# 21       Mabel   F     808  1880
# 22      Bessie   F     794  1880
# 23      Jennie   F     793  1880
# 24    Gertrude   F     787  1880
# 25       Julia   F     783  1880
# 26      Hattie   F     769  1880
# ...

# %%
names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# 5         Margaret   F    1578  1880  0.017342
# 6              Ida   F    1472  1880  0.016177
# 7            Alice   F    1414  1880  0.015540
# 8           Bertha   F    1320  1880  0.014507
# 9            Sarah   F    1288  1880  0.014155
# 10           Annie   F    1258  1880  0.013825
# 11           Clara   F    1226  1880  0.013474
# 12            Ella   F    1156  1880  0.012704
# 13        Florence   F    1063  1880  0.011682
# 14            Cora   F    1045  1880  0.011484
# 15          Martha   F    1040  1880  0.011429
# 16           Laura   F    1012  1880  0.011122
# 17          Nellie   F     995  1880  0.010935
# 18           Grace   F     982  1880  0.010792
# ...

# %%
import numpy as np

# %%
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %%
def get_top1000(group):
    return group.sort_values(by = 'births', ascending = False)[:1000]

# %%
grouped=names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
top1000.index = np.arange(len(top1000))

# %%
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.077643
# 1            Anna   F    2604  1880  0.028618
# 2            Emma   F    2003  1880  0.022013
# 3       Elizabeth   F    1939  1880  0.021309
# 4          Minnie   F    1746  1880  0.019188
# 5        Margaret   F    1578  1880  0.017342
# 6             Ida   F    1472  1880  0.016177
# 7           Alice   F    1414  1880  0.015540
# 8          Bertha   F    1320  1880  0.014507
# 9           Sarah   F    1288  1880  0.014155
# 10          Annie   F    1258  1880  0.013825
# 11          Clara   F    1226  1880  0.013474
# 12           Ella   F    1156  1880  0.012704
# 13       Florence   F    1063  1880  0.011682
# 14           Cora   F    1045  1880  0.011484
# 15         Martha   F    1040  1880  0.011429
# 16          Laura   F    1012  1880  0.011122
# 17         Nellie   F     995  1880  0.010935
# 18          Grace   F     982  1880  0.010792
# ...

# %%
pieces = []
for year, group in names.groupby(['year', 'sex']):
    print(year)
    pieces.append(group.sort_values(by='births', ascending=False)[:1000])    
top1000 = pd.concat(pieces, ignore_index=True)
# Out:
# (1880, 'F')
# (1880, 'M')
# (1881, 'F')
# (1881, 'M')
# (1882, 'F')
# (1882, 'M')
# (1883, 'F')
# (1883, 'M')
# (1884, 'F')
# (1884, 'M')
# (1885, 'F')
# (1885, 'M')
# (1886, 'F')
# (1886, 'M')
# (1887, 'F')
# (1887, 'M')
# (1888, 'F')
# (1888, 'M')
# (1889, 'F')
# (1889, 'M')
# (1890, 'F')
# (1890, 'M')
# (1891, 'F')
# (1891, 'M')
# (1892, 'F')
# (1892, 'M')
# (1893, 'F')
# (1893, 'M')
# (1894, 'F')
# (1894, 'M')
# (1895, 'F')
# (1895, 'M')
# (1896, 'F')
# (1896, 'M')
# (1897, 'F')
# (1897, 'M')
# (1898, 'F')
# (1898, 'M')
# (1899, 'F')
# (1899, 'M')
# (1900, 'F')
# (1900, 'M')
# (1901, 'F')
# (1901, 'M')
# (1902, 'F')
# (1902, 'M')
# (1903, 'F')
# (1903, 'M')
# (1904, 'F')
# (1904, 'M')
# (1905, 'F')
# (1905, 'M')
# (1906, 'F')
# (1906, 'M')
# (1907, 'F')
# (1907, 'M')
# (1908, 'F')
# (1908, 'M')
# (1909, 'F')
# (1909, 'M')
# (1910, 'F')
# (1910, 'M')
# (1911, 'F')
# (1911, 'M')
# (1912, 'F')
# (1912, 'M')
# (1913, 'F')
# (1913, 'M')
# (1914, 'F')
# (1914, 'M')
# (1915, 'F')
# ...

# %%
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.077643
# 1            Anna   F    2604  1880  0.028618
# 2            Emma   F    2003  1880  0.022013
# 3       Elizabeth   F    1939  1880  0.021309
# 4          Minnie   F    1746  1880  0.019188
# 5        Margaret   F    1578  1880  0.017342
# 6             Ida   F    1472  1880  0.016177
# 7           Alice   F    1414  1880  0.015540
# 8          Bertha   F    1320  1880  0.014507
# 9           Sarah   F    1288  1880  0.014155
# 10          Annie   F    1258  1880  0.013825
# 11          Clara   F    1226  1880  0.013474
# 12           Ella   F    1156  1880  0.012704
# 13       Florence   F    1063  1880  0.011682
# 14           Cora   F    1045  1880  0.011484
# 15         Martha   F    1040  1880  0.011429
# 16          Laura   F    1012  1880  0.011122
# 17         Nellie   F     995  1880  0.010935
# 18          Grace   F     982  1880  0.010792
# ...

# %%
boys = top1000[top1000.sex=='M']

# %%
girls = top1000[top1000.sex == 'F']

# %%
top1000.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077643
# 1       Anna   F    2604  1880  0.028618
# 2       Emma   F    2003  1880  0.022013
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188

# %%
total_births = top1000.pivot_table('births', index='year', columns= 'name', aggfunc=sum)

# %%
total_births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 1880 to 2010
# Columns: 6868 entries, Aaden to Zuri
# dtypes: float64(6868)
# memory usage: 6.9 MB

# %%
subset = total_births[['John', 'Harry', 'Mary', 'Marilyn']]

# %%
subset
# Out:
# name     John   Harry     Mary  Marilyn
# year
# 1880   9701.0  2158.0   7092.0      NaN
# 1881   8795.0  2002.0   6948.0      NaN
# 1882   9597.0  2246.0   8179.0      NaN
# 1883   8934.0  2116.0   8044.0      NaN
# 1884   9427.0  2338.0   9253.0      NaN
# 1885   8801.0  2209.0   9166.0      NaN
# 1886   9074.0  2272.0   9923.0      NaN
# 1887   8165.0  2070.0   9935.0      NaN
# 1888   9300.0  2772.0  11804.0      NaN
# 1889   8600.0  2559.0  11690.0      NaN
# 1890   8557.0  2357.0  12113.0      NaN
# 1891   7725.0  2141.0  11743.0      NaN
# 1892   9093.0  2471.0  13224.0      NaN
# 1893   8110.0  2264.0  12839.0      NaN
# 1894   8298.0  2189.0  13199.0      NaN
# 1895   8382.0  2143.0  13493.0      NaN
# 1896   8189.0  2091.0  13868.0      NaN
# 1897   7596.0  1880.0  13475.0      NaN
# 1898   8215.0  2129.0  14456.0      NaN
# 1899   7030.0  1732.0  13222.0      NaN
# 1900   9880.0  2272.0  16785.0      NaN
# 1901   6938.0  1594.0  13195.0      NaN
# ...

# %%
subset.plot(subplots=True, figsize=(12, 10), grid=False, title = "Number of births per year")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1357e3198>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1358f31d0>], dtype=object)

# %%
table = top1000.pivot_table('prop', index='year', columns='sex', aggfunc=sum)

# %%
table
# Out:
# sex          F         M
# year
# 1880  1.000000  0.997375
# 1881  1.000000  1.000000
# 1882  0.998702  0.995646
# 1883  0.997596  0.998566
# 1884  0.993156  0.994539
# 1885  0.992251  0.995501
# 1886  0.989504  0.995035
# 1887  0.988279  0.996697
# 1888  0.984241  0.992429
# 1889  0.984061  0.994981
# 1890  0.982566  0.992749
# 1891  0.982177  0.993725
# 1892  0.979746  0.988815
# 1893  0.980001  0.991720
# 1894  0.978571  0.989048
# 1895  0.975479  0.989071
# 1896  0.975660  0.988041
# 1897  0.976558  0.989349
# 1898  0.972806  0.987197
# 1899  0.975170  0.990115
# 1900  0.967760  0.979702
# 1901  0.972304  0.989603
# 1902  0.970467  0.985749
# 1903  0.969490  0.986020
# 1904  0.968142  0.982502
# 1905  0.967038  0.981650
# 1906  0.967535  0.981759
# 1907  0.964942  0.976975
# 1908  0.964500  0.976409
# 1909  0.962744  0.973412
# ...        ...       ...
# 1981  0.867232  0.944762
# 1982  0.868208  0.944435
# 1983  0.871602  0.945170
# 1984  0.870201  0.944705
# ...

# %%
table.plot(title='Sum of table1000.prop by year and sex', yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 10))

# %%
df = boys[boys.year ==2010]

# %%
df.head()
# Out:
#            name sex  births  year      prop
# 260877    Jacob   M   21875  2010  0.011523
# 260878    Ethan   M   17866  2010  0.009411
# 260879  Michael   M   17133  2010  0.009025
# 260880   Jayden   M   17030  2010  0.008971
# 260881  William   M   16870  2010  0.008887

# %%
prop_custom= df.sort_values(by='prop', ascending=False)

# %%
prop_custom.prop
# Out:
# 260877    0.011523
# 260878    0.009411
# 260879    0.009025
# 260880    0.008971
# 260881    0.008887
# 260882    0.008762
# 260883    0.008576
# 260884    0.008259
# 260885    0.008114
# 260886    0.008093
# 260887    0.008027
# 260888    0.007758
# 260889    0.007446
# 260890    0.007424
# 260891    0.007397
# 260892    0.007350
# 260893    0.007345
# 260894    0.007235
# 260895    0.007224
# 260896    0.007194
# 260897    0.006701
# 260898    0.006469
# 260899    0.006261
# 260900    0.006203
# 260901    0.006159
# 260902    0.006018
# 260903    0.005936
# 260904    0.005809
# 260905    0.005776
# 260906    0.005716
#             ...
# 261850    0.000106
# 261846    0.000106
# 261848    0.000106
# 261847    0.000106
# 261851    0.000105
# 261852    0.000105
# 261853    0.000105
# 261854    0.000105
# 261855    0.000105
# 261856    0.000105
# 261857    0.000104
# 261858    0.000104
# 261862    0.000104
# 261864    0.000104
# 261863    0.000104
# 261861    0.000104
# ...

# %%
get_last_letter = lambda x:x[-1]

# %%
last_letters= names.name.map(get_last_letter)

# %%
last_letters.name = 'last_letter'

# %%
names.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077643
# 1       Anna   F    2604  1880  0.028618
# 2       Emma   F    2003  1880  0.022013
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188

# %%
table = names.pivot_table('births', index=last_letters, columns = ['sex', 'year'], aggfunc= sum)

# %%
table
# Out:
# sex                F                                                        \
# year            1880     1881     1882     1883     1884     1885     1886
# last_letter
# a            31446.0  31581.0  36536.0  38330.0  43680.0  45408.0  49100.0
# b                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# c                NaN      NaN      5.0      5.0      NaN      NaN      NaN
# d              609.0    607.0    734.0    810.0    916.0    862.0   1007.0
# e            33378.0  34080.0  40399.0  41914.0  48089.0  49616.0  53884.0
# f                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# g                7.0      5.0     12.0      8.0     24.0     11.0     18.0
# h             4863.0   4784.0   5567.0   5701.0   6602.0   6624.0   7146.0
# i               61.0     78.0     81.0     76.0     84.0     92.0     85.0
# j                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
subtable = table.reindex(columns =[1910, 1960, 2010], level = 'year')

# %%
subtable
# Out:
# sex                 F                            M
# year             1910      1960      2010     1910      1960      2010
# last_letter
# a            108376.0  691247.0  670605.0    977.0    5204.0   28438.0
# b                 NaN     694.0     450.0    411.0    3912.0   38859.0
# c                 5.0      49.0     946.0    482.0   15476.0   23125.0
# d              6750.0    3729.0    2607.0  22111.0  262112.0   44398.0
# e            133569.0  435013.0  313833.0  28655.0  178823.0  129012.0
# f                 NaN      20.0      97.0    152.0    9224.0    2255.0
# g                57.0     318.0     657.0    437.0   20235.0    2666.0
# h             20427.0   73247.0  133424.0   8848.0   80841.0   98090.0
# i               605.0   80812.0   55820.0    164.0    1286.0   42956.0
# j                 NaN       NaN     159.0      NaN       NaN    1459.0
# k                48.0     315.0     626.0   7104.0  105315.0   35198.0
# ...

# %%
subtable.sum()
# Out:
# sex  year
# F    1910     396416.0
#      1960    2022062.0
#      2010    1759010.0
# M    1910     194198.0
#      1960    2132588.0
#      2010    1898382.0
# dtype: float64

# %%
letter_prop = subtable/subtable.sum()

# %%
letter_prop
# Out:
# sex                 F                             M
# year             1910      1960      2010      1910      1960      2010
# last_letter
# a            0.273390  0.341853  0.381240  0.005031  0.002440  0.014980
# b                 NaN  0.000343  0.000256  0.002116  0.001834  0.020470
# c            0.000013  0.000024  0.000538  0.002482  0.007257  0.012181
# d            0.017028  0.001844  0.001482  0.113858  0.122908  0.023387
# e            0.336941  0.215133  0.178415  0.147556  0.083853  0.067959
# f                 NaN  0.000010  0.000055  0.000783  0.004325  0.001188
# g            0.000144  0.000157  0.000374  0.002250  0.009488  0.001404
# h            0.051529  0.036224  0.075852  0.045562  0.037907  0.051670
# i            0.001526  0.039965  0.031734  0.000844  0.000603  0.022628
# j                 NaN       NaN  0.000090       NaN       NaN  0.000769
# k            0.000121  0.000156  0.000356  0.036581  0.049384  0.018541
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 1, figsize =(10, 8))
letter_prop['M'].plot(kind='bar', rot=0, ax=axes[0], title='Male')
letter_prop['F'].plot(kind='bar', rot=0, ax=axes[0], title='Female')

# %%
letter_prop = table/table.sum()

# %%
letter_prop
# Out:
# sex                 F                                                    \
# year             1880      1881      1882      1883      1884      1885
# last_letter
# a            0.345587  0.343440  0.338764  0.341251  0.338550  0.341270
# b                 NaN       NaN       NaN       NaN       NaN       NaN
# c                 NaN       NaN  0.000046  0.000045       NaN       NaN
# d            0.006693  0.006601  0.006806  0.007211  0.007100  0.006478
# e            0.366819  0.370616  0.374582  0.373159  0.372722  0.372896
# f                 NaN       NaN       NaN       NaN       NaN       NaN
# g            0.000077  0.000054  0.000111  0.000071  0.000186  0.000083
# h            0.053444  0.052025  0.051618  0.050756  0.051170  0.049784
# i            0.000670  0.000848  0.000751  0.000677  0.000651  0.000691
# j                 NaN       NaN       NaN       NaN       NaN       NaN
# k            0.000143  0.000163  0.000102  0.000151  0.000163  0.000135
# ...

# %%
letter_prop = table/table.sum()

# %%
dny_ts = letter_prop.loc[['d', 'n', 'y'], 'M'].T

# %%
dny_ts.head()
# Out:
# last_letter         d         n         y
# year
# 1880         0.083055  0.153213  0.075760
# 1881         0.083247  0.153214  0.077451
# 1882         0.085340  0.149560  0.077537
# 1883         0.084066  0.151646  0.079144
# 1884         0.086120  0.149915  0.080405

# %%
dny_ts.plot()

# %%
all_names = top1000.name.unique()

# %%
all_names
# Out:
# array(['Mary', 'Anna', 'Emma', ..., 'Yousef', 'Joziah', 'Maxton'], dtype=object)

# %%
mask = np.array(['lesl' in x.lower() for x in all_names])

# %%
mask
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
lesley_like = all_names[mask]

# %%
lesley_like
# Out:
# array(['Leslie', 'Lesley', 'Leslee', 'Lesli', 'Lesly'], dtype=object)

# %%
filtered = top1000[top1000.name.isin(lesley_like)]
filtered.groupby('name').births.sum()
# Out:
# name
# Leslee      1082
# Lesley     35022
# Lesli        929
# Leslie    370429
# Lesly      10067
# Name: births, dtype: int64
